# %% [markdown]
# # **Actividad Mortalidad**
# AD2003B.403
# Semestre Febrero Junio 2023

# %% [markdown]
# # ***PORTADA*** de cada pareja.

# %% [markdown]
# **Mortalidad Materna en México en el periodo 2003 - 2019**
#
# De acuerdo con la OMS una muerte materna “es la muerte de una mujer mientras que está embarazada o dentro de los 42 días de haber terminado un embarazo, independientemente de la duración y la localización del embarazo, por cualquier causa vinculada o agravada por el embarazo o su manejo, pero no por causas accidentales o incidentales y en consecuencia, constituye un importante indicador del nivel de desarrollo de un país y de la capacidad resolutiva de su sistema de salud”.
#
#  **Objetivo general:** Analizar la relación entre la Causas de mortalidad con la asistencia médica, edad, estado de residencia y ocupación de las pacientes.

# %% [markdown]
# ***Realiza las investigaciones necesarias*** para llevar a cabo lo solicitado.

# %%
#Importa aquí todas las librerías que vayas a utilizar

# %% [markdown]
# # **1.- Importar datos de defunciones y pacientes en sus correspondientes dataframes**.
# Coloca los archivos de datos en una carpeta "BD" dentro de tu github

# %% [markdown]
# **CONOCER** los datos de los dataframes.
#
# Conocer todos los datos, utiliza la funciones necesarias para conocerlos a fondo. Tanto los metadatos como propiamento los datos de ambos dataframes.

# %%
#imprime las primeras 12 filas de df_defunciones

# %% [markdown]
# #### Revisar cuantas filas, cuántas columnas y qué tipos de datos tienen los dataframes

# %%
#imprime un mensaje que diga: La base de datos df_defunciones tiene _ filas y _ columnas
#debe de imprimir los valores correctos para ambas dimensiones

# %%
#indicar el tipo de dato por columna

# %% [markdown]
# #### Identificar NaNs

# %%
#imprimir el conteo de valores nulos por columna

# %%
#indicar el tipo de dato por columna

# %% [markdown]
# #### Cambiar tipo de datos para Año de nacimiento
# Investigar el uso de **astype**

# %%
#crea un diccionario de nombre 'diccionario_de_conversion'
#la llave y el valor deberán ser el nombre de la columna y el tipo de dato a cambiar
#cambiar de float64 a object

# %%
#con la función .astype() utiliza el diccionario creado en el paso anterior
#esto cambiará el tipo de dato de la columna de float64 a object
#df["datoaconvertir"]=df["datoaconvertir"].astype("tipodedatonuevo")

# %%
#verifica que el cambio se haya hecho

# %% [markdown]
# #### Identificar NaNs en los dataframe

# %%
#imprimir el conteo de valores nulos por columna

# %% [markdown]
# Cambiar NaNs por "NO ESPECIFICADO" en AñoDeNacimiento

# %%
#en la columna 'AñoDeNacimiento' reemplaza los NaNs por el string 'NO ESPECIFICADO'
#imprime las primeras 5 filas del dataframe para revisar si el cambio se realizó de manera correcta

# %%
#imprimir el conteo de valores nulos por columna

# %% [markdown]
# #### **Unir ambos datasets**

# %%
#guarda la concatenación de ambas tablas en una variable llamada 'dfDatos'

# %%
#revisa si la unión de las tablas fue correcta
#df_full deberá tener 19776 filas y 58 columnas
# De no salirte estos datos, consulta la ayuda de merge

# %%
#imprime las primeras 5 filas de dfDatos

# %%
#imprime las primeras 5 filas de la columna 'IdCausaCIE'

# %%
#imprime las primeras 5 filas de la columna 'CausaCIE'

# %%
#como podrás notar la columna 'causa_cie' tiene repetido el valor de la columna 'id_causa_cie'
#utiliza la función .str.split() para dividir los valores de 'causa_cie' en sus respectivas columnas
# EL objetivo es que la columnas CausaCIE solo tenga la causa sin el ID

# Crea un un df temporal para guardar la columas con la causa cie y con el  el id causa cie
# utiliza str.split,  investigar como se usa. especial atencion en los arguemntos "n" y "expand"


#Verificar el tipo de dato del df temporal, de ser necesario convierte a DataFrame


#COloca en la columnas CausaCIE el dato sin el ID

# %% [markdown]
# **Realiza las acciones de tranformacion y limpieza adicionales que consideres necearias**

# %% [markdown]
# #### **Teniendo la tabla completa, contesta las siguientes preguntas**
#
# 1. ¿Qué Entidad Federativa tiene más ocurrencias de muertes
# maternas?
# 2. ¿Cuál es el rango de edad con mayor incidencia de muertes maternas?
# 3. ¿Cuántas defunciones hay con asistencia médica, sin asistencia médica o no especificada según la derechohabiencia de las pacientes?
# 4. ¿Cuál es la causa más común de muerte materna?
# 5. ¿Cuál es la causa más común de muerte materna por Entidad Federativa y por grupo de edad quinquenal?
# 6. ¿Cuántas muertes hay por ocupación de las pacientes?
# 7. ¿Cuántas defunciones hay por escolaridad de la paciente?
# 8. ¿Hay más o menos incidencias de muerte materna de acuerdo a la ocupación, la escolaridad y la derechohabiencia de las pacientes?
#
# **Responde a las preguntas con una mensaje y con gráfica.**
#
# **Manda los resultados a un archivo de excel, cada punto en una hoja.**

# %%
# 1. ¿Qué Entidad Federativa tiene más ocurrencias de muertes maternas?

#imprime un mensaje que diga: El estado con más ocurrencias es _ con un valor de _

#debe de imprimir los valores correctos para ambas posiciones

# %%
# 2. ¿Cuál es el rango de edad con mayor incidencia de muertes maternas?

#imprime un mensaje que diga: El rango de edad con mayor incidencia de muertes es _ con _ ocurrencias

#debe de imprimir los valores correctos para ambas posiciones

# %%
# 3. ¿Cuántas defunciones hay con asistencia médica, sin asistencia médica o no especificada según la derechohabiencia de las pacientes?
#agrupa los datos dependiendo de las columnas de interés

# %%
# 4. ¿Cuál es la causa más común de muerte materna?

#imprime un mensaje que diga: La causa más común de muerte materna es _ con _ incidencias
#debe de imprimir los valores correctos para ambas posiciones

# %%
# 5. ¿Cuál es la causa más común de muerte materna por Entidad Federativa y por grupo de edad?

# %%
# 6. ¿Cuántas muertes hay por ocupación de las pacientes?

# %%
# 7. ¿Qué escolaridad tiene la mayor parte de las mujeres que inciden en casos de muerte materna?

#imprime un mensaje que diga: La escolaridad con mayor incidencia de muerte materna es _ con _ pacientes
#debe de imprimir los valores correctos para ambas posiciones

# %%
# 8. ¿Hay más o menos incidencias de muerte materna de acuerdo a la ocupación, la escolaridad y la derechohabiencia de las pacientes? 

#regresa el conteo de valores por condición con .value_counts()

# %% [markdown]
# # **EXTRAS**
# Pueden colocar anlisis adicionales que les daran puntos extras de ser necesarios.
